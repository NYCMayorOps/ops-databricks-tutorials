# %%
# %r
#sparklyr is the the modern way to do this, but it isn't compatible

# %% [markdown]
# Ask your admin to enable R on the cluster. In the cluster configuration, under Advanced Options > Spark Config or Cluster Policies, the admin can set spark.databricks.allowedLanguages to include r.
# For example:
#
# spark.databricks.allowedLanguages sql,python,scala,r

# %%
# %r
#SparkR is depricated
library(SparkR)

# %%
# %r
#this doesn't work
library(sparklyr)
sc <- spark_connect(method = "databricks")

# %%
# %r
#sparlyr doesn't seem to work so we'll just use the SparkR package
library(SparkR)
sparkR.session()

# %%
# %sql
SELECT COUNT(*)
FROM scorecard_fulcrum.scorecard_fulcrum_records.scorecard_gold_table_citywide

# %%
# %sql
SHOW TABLES FROM scorecard_fulcrum.scorecard_fulcrum_records

# %%
# %r
#library(SparkR)
df = tableToDF("scorecard_fulcrum.scorecard_fulcrum_records.scorecard_gold_table_citywide")
head(df)
